# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df["Cabin"].value_counts()
#df["Cabin"]=df["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
#df["Age"]=df.["Age"].mean()

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[df["Sex"]=="male"]["Pclass"].value_counts()
# Out:
# 3    347
# 1    122
# 2    108
# Name: Pclass, dtype: int64

# %%
df[df["Sex"]=="female"]["Pclass"].value_counts()
# Out:
# 3    144
# 1     94
# 2     76
# Name: Pclass, dtype: int64

# %%
df[(df["Sex"]=="male") & (df["Pclass"]==2)]
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 17            18         1       2   Williams, Mr. Charles Eugene  male   NaN
# 20            21         0       2           Fynney, Mr. Joseph J  male  35.0
# 21            22         1       2          Beesley, Mr. Lawrence  male  34.0
# 33            34         0       2          Wheadon, Mr. Edward H  male  66.0
# 70            71         0       2     Jenkin, Mr. Stephen Curnow  male  32.0
# ..           ...       ...     ...                            ...   ...   ...
# 848          849         0       2              Harper, Rev. John  male  28.0
# 861          862         0       2    Giles, Mr. Frederick Edward  male  21.0
# 864          865         0       2         Gill, Mr. John William  male  24.0
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
#
# ...

# %%
round(df["Fare"].mean(),2)
# Out:
# 32.2

# %%
round(df["Fare"].std(),2)
# Out:
# 49.69

# %% [markdown]
# # Визуализация

# %%
import pandas as pd

pd.plotting.scatter_matrix(df[["Age", "Fare", "Pclass", "Sex", "SibSp", "Parch", "Embarked", "Survived"]], figsize=(20,15));

# %%
df.hist(figsize=(20,15),color="darkcyan",bins=20);

# %%
df.boxplot(column =["Fare","Pclass"]);

# %%
sns.countplot(x="Survived", hue="Sex", data=df);

# %%
sns.countplot(x="Survived", hue="Pclass", data=df);

# %%
scatter = plt.scatter(df["Age"], df["Fare"], c=df["Survived"], cmap='bwr', s=20);
handles, labels = scatter.legend_elements()
labels = ['Not survived','Survived']
plt.legend(handles, labels)
plt.show()
# Out:
# <__array_function__ internals>:5: UserWarning: Warning: converting a masked element to nan.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py:633: UserWarning: Warning: converting a masked element to nan.
#   if self._useLocale else fmt % arg)

# %%
df[df["Age"]==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
sns.histplot(x=df["Age"], data=df, hue="Survived", kde=True, bins=3);#выживаемость молодежи 0.42, пожилых 0.3

# %%
ab = pd.read_csv("Social_network_users.csv", sep=",")

# %%
ab.head()
# Out:
#                           FullName  BirthDate Married   Sex  \
# 0          MikheiIraklievichAverin  4/28/1973     Yes  Male
# 1        JulianaLopatinaGordeevich   2/8/1976      No  Male
# 2         DavidPlatonovichKornilov   1/2/1976     Yes  Male
# 3      YakhlakovaFedotMartianovich  7/11/1973      No  Male
# 4  ReshetnikovaSebastianFedorovich  3/13/1987     Yes  Male
#
#                      Hobbies        Company            Education  OnlineTime  \
# 0                   Painting       Salesman  Secondaryvocational         1.0
# 1  Playingamusicalinstrument  Stateemployee  Universityeducation         0.5
# 2                     Hiking  Stateemployee  Universityeducation         3.0
# 3                      Sport    Businessman  Universityeducation         1.0
# 4              Photographing     Unemployed  Secondaryvocational         1.0
#
#    OnlineDay
# 0        100
# 1        200
# 2         56
# 3        100
# 4          7
